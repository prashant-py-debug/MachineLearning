# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os
from tensorflow.keras.utils import Progbar
tf.__version__
# Out:
# '2.3.1'

# %%
batch_size = 64
epochs = 50
z_dim = 100
c_lambda = 10
train_size = 10000
shuffle_buffer = 1000

# %%
def decode_img(file_path):
    file = tf.io.read_file(file_path)
    img = tf.image.decode_jpeg(file, channels=3)
    img = tf.image.resize(img , [224,224])
    img = tf.image.convert_image_dtype(img, tf.float32)
    img = img / 255.0
    return img   



img_path = "/kaggle/input/celeba-dataset/img_align_celeba/img_align_celeba/"
ds_train_paths = tf.data.Dataset.list_files(str(img_path + '*.jpg'))
ds_train_paths = ds_train_paths.take(train_size)

ds_train = ds_train_paths.map(decode_img).cache().shuffle(shuffle_buffer).batch(batch_size, drop_remainder=True)

# %%
def get_noise(batch_size , z_dim):
    return tf.random.normal([batch_size,z_dim])

# %%
def generator():
    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Dense(7*7*512 , input_shape = (z_dim,)))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.LeakyReLU())
    
    model.add(tf.keras.layers.Reshape((7,7,512)))
    
    model.add(tf.keras.layers.UpSampling2D()) #14x14
    model.add(tf.keras.layers.Conv2D(256 , (5,5) , strides = (1,1), padding = "same")) #14x14
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.LeakyReLU())

    model.add(tf.keras.layers.UpSampling2D())  #28X28
    model.add(tf.keras.layers.Conv2D(128 , (5,5) , strides = (1,1), padding = "same")) #28x28
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.LeakyReLU())

    model.add(tf.keras.layers.UpSampling2D())  #56X56
    model.add(tf.keras.layers.Conv2D(64 , (5,5) , strides = (1,1), padding = "same")) #56x56
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.LeakyReLU())
        
    model.add(tf.keras.layers.UpSampling2D())  #112X112
    model.add(tf.keras.layers.Conv2D(32 , (5,5) , strides = (1,1), padding = "same")) #112x112
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.LeakyReLU())
        
    model.add(tf.keras.layers.UpSampling2D())  #224X224
    model.add(tf.keras.layers.Conv2D(3 , (5,5) , strides = (1,1), padding = "same" , activation = "tanh")) #28x28
        
    return model

# %%
#testing generator
s = tf.random.normal([1,z_dim])

gen = generator()
x = gen(s)
assert x.shape == (1,224,224,3)

# %%
def critic():
    model = tf.keras.Sequential()
    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Conv2D(64,(5,5), strides = (2,2) , padding = "same"  ,input_shape = (224,224,3)))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.LeakyReLU())
    
    
    model.add(tf.keras.layers.Conv2D(128,(5,5), strides = (2,2) , padding = "same"))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.LeakyReLU())
    
    model.add(tf.keras.layers.Conv2D(256,(5,5), strides = (2,2) , padding = "same"))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.LeakyReLU())
    
    model.add(tf.keras.layers.Flatten())
    model.add(tf.keras.layers.Dense(1))
    
    
    return model

# %%
#testing Critic
crit = critic()
s = tf.random.normal([1,224,224,3])
x = crit(s)
x
# Out:
# <tf.Tensor: shape=(1, 1), dtype=float32, numpy=array([[-0.00250522]], dtype=float32)>

# %%
@tf.function
def get_gradient(crit,real,fake,epsilon):
    
    mixed = real * epsilon + (1 - epsilon)* fake
    with tf.GradientTape() as gtape:
        gtape.watch(mixed)
        mixed_score = crit(mixed , training = True)
        
    grad = gtape.gradient(mixed_score , mixed)
    return grad

# %%
def gradient_penalty(gradient):
    
    grad_norm = tf.norm(gradient)
    penalty = tf.reduce_mean((grad_norm - 1)**2)
    
    return penalty

# %%
def gen_loss(fake_output):
    
    
    loss = -1 * tf.reduce_mean(fake_output)
    return loss

# %%
def critic_loss(fake_output , real_output , gp , c_lambda):
    
    
    loss = -(tf.reduce_mean(real_output) - tf.reduce_mean
             (fake_output)) + (c_lambda * gp)
    return loss

# %%
#testing gradient
real = tf.random.normal([1,224,224,3])
fake = tf.random.normal([1,224,224,3])
grad = get_gradient(crit ,real = real , fake = fake , epsilon = 0.1)
grad.shape
# Out:
# TensorShape([1, 224, 224, 3])

# %%
#testing gradient_panalty
penalty = gradient_penalty(grad)
penalty
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=0.10759969>

# %%
#testinf critic's loss
fake_output = crit(fake)
real_output = crit(real)

loss = critic_loss(fake_output, real_output , penalty , 0.5)
loss
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=0.08636968>

# %%
gen_optimizer = tf.keras.optimizers.Adam(0.002,0.5,0.99)
critic_optimizer = tf.keras.optimizers.Adam(0.002,0.5,0.99)

# %%
@tf.function
def train_step(real_images):
    
    
    
    with tf.GradientTape() as gen_tape , tf.GradientTape() as crit_tape:
        
        noises = get_noise(real_images.shape[0] , z_dim)
        fake_images = gen(noises,training = True)
        fake_outputs = crit(fake_images , training = True)
        real_outputs = crit(real_images , training = True)
        epsilon = tf.random.uniform([real_images.shape[0],224,224,3])
        grad = get_gradient(crit,real = real_images,fake = fake_images,epsilon = epsilon)
        penalty = gradient_penalty(grad)
        ######################################################################
        g_loss = gen_loss(fake_outputs )
        c_loss = critic_loss(fake_outputs, real_outputs , penalty , c_lambda )
        
    gen_grad = gen_tape.gradient(g_loss , gen.trainable_variables)
    critic_grad = crit_tape.gradient(c_loss, crit.trainable_variables)
    
    gen_optimizer.apply_gradients(zip(gen_grad ,gen.trainable_variables ))
    critic_optimizer.apply_gradients(zip(critic_grad , crit.trainable_variables))
    
    return g_loss , c_loss

# %%
def train(dataset , epochs):
    
    
    mean_gen_loss_list = []
    mean_critic_loss_list = []
    
    for epoch in range(epochs):
        gen_loss_list = []
        critic_loss_list = []
        
        progress_bar = Progbar(train_size)
        for image in dataset:
            g_loss, c_loss , = train_step(image)
            gen_loss_list.append(g_loss)
            critic_loss_list.append(c_loss)
            
            progress_bar.add(batch_size)
        
        
        mean_g_loss = sum(gen_loss_list)/len(gen_loss_list)
        mean_c_loss = sum(critic_loss_list)/len(critic_loss_list)
        mean_gen_loss_list.append(mean_g_loss)
        mean_critic_loss_list.append(mean_c_loss)    
            
        print (f'Epoch {epoch+1}, gen loss={mean_g_loss},critic loss={mean_c_loss}')
        
    return mean_gen_loss_list , mean_critic_loss_list

# %%
G_loss , C_loss = train(ds_train , epochs)
# Out:
#  9984/10000 [============================>.] - ETA: 0sEpoch 1, gen loss=1.4770663976669312,critic loss=80.03632354736328
#  9984/10000 [============================>.] - ETA: 0sEpoch 2, gen loss=3.5086469650268555,critic loss=301.76336669921875
#  9984/10000 [============================>.] - ETA: 0sEpoch 3, gen loss=2.520690679550171,critic loss=151.21389770507812
#  9984/10000 [============================>.] - ETA: 0sEpoch 4, gen loss=5.414589881896973,critic loss=-1.593295931816101
#  9984/10000 [============================>.] - ETA: 0sEpoch 5, gen loss=0.6481605768203735,critic loss=82.47467041015625
#  9984/10000 [============================>.] - ETA: 0sEpoch 6, gen loss=-1.8137704133987427,critic loss=650.3749389648438
#  9984/10000 [============================>.] - ETA: 0sEpoch 7, gen loss=-1.7128448486328125,critic loss=-1.8800735473632812
#  9984/10000 [============================>.] - ETA: 0sEpoch 8, gen loss=2.7679524421691895,critic loss=33.93324661254883
#  9984/10000 [============================>.] - ETA: 0sEpoch 9, gen loss=6.983990669250488,critic loss=87.0270767211914
#  9984/10000 [============================>.] - ETA: 0sEpoch 10, gen loss=9.538405418395996,critic loss=-2.187858819961548
#  9984/10000 [============================>.] - ETA: 0sEpoch 11, gen loss=5.2580180168151855,critic loss=35.25108337402344
#  9984/10000 [============================>.] - ETA: 0sEpoch 12, gen loss=-0.5033161640167236,critic loss=69.75794219970703
#  9984/10000 [============================>.] - ETA: 0sEpoch 13, gen loss=13.452536582946777,critic loss=231.79823303222656
#  9984/10000 [============================>.] - ETA: 0sEpoch 14, gen loss=7.677019119262695,critic loss=53.49843978881836
#  9984/10000 [============================>.] - ETA: 0sEpoch 15, gen loss=2.373528003692627,critic loss=55.51127243041992
#  9984/10000 [============================>.] - ETA: 0sEpoch 16, gen loss=-17.273181915283203,critic loss=178.734619140625
#  9984/10000 [============================>.] - ETA: 0sEpoch 17, gen loss=-6.955265045166016,critic loss=92.60865783691406
#  9984/10000 [============================>.] - ETA: 0sEpoch 18, gen loss=-21.23682403564453,critic loss=36.184810638427734
#  9984/10000 [============================>.] - ETA: 0sEpoch 19, gen loss=-21.028987884521484,critic loss=71.40374755859375
#  9984/10000 [============================>.] - ETA: 0sEpoch 20, gen loss=-19.206340789794922,critic loss=-2.212402105331421
#  9984/10000 [============================>.] - ETA: 0sEpoch 21, gen loss=-18.39776039123535,critic loss=33.66068649291992
#  9984/10000 [============================>.] - ETA: 0sEpoch 22, gen loss=-23.17304229736328,critic loss=-1.4478833675384521
#  9984/10000 [============================>.] - ETA: 0sEpoch 23, gen loss=-31.77875518798828,critic loss=62.78247833251953
#  9984/10000 [============================>.] - ETA: 0sEpoch 24, gen loss=-28.575532913208008,critic loss=-4.426232814788818
#  9984/10000 [============================>.] - ETA: 0sEpoch 25, gen loss=-30.748008728027344,critic loss=-3.833221912384033
#  9984/10000 [============================>.] - ETA: 0sEpoch 26, gen loss=-38.81710433959961,critic loss=4.136648654937744
#  9984/10000 [============================>.] - ETA: 0sEpoch 27, gen loss=-39.88775634765625,critic loss=0.2493748962879181
#  9984/10000 [============================>.] - ETA: 0sEpoch 28, gen loss=-43.325401306152344,critic loss=-0.5319043397903442
#  9984/10000 [============================>.] - ETA: 0sEpoch 29, gen loss=-42.198638916015625,critic loss=-1.434418797492981
#  9984/10000 [============================>.] - ETA: 0sEpoch 30, gen loss=-43.09894943237305,critic loss=-1.1973562240600586
#  9984/10000 [============================>.] - ETA: 0sEpoch 31, gen loss=-38.63344955444336,critic loss=-1.4824832677841187
#  9984/10000 [============================>.] - ETA: 0sEpoch 32, gen loss=-39.66718292236328,critic loss=-1.2710613012313843
#  9984/10000 [============================>.] - ETA: 0sEpoch 33, gen loss=-46.739593505859375,critic loss=-1.1537026166915894
#  9984/10000 [============================>.] - ETA: 0sEpoch 34, gen loss=-52.055660247802734,critic loss=-1.3881793022155762
#  9984/10000 [============================>.] - ETA: 0sEpoch 35, gen loss=-49.55571746826172,critic loss=-1.2719587087631226
#  9984/10000 [============================>.] - ETA: 0sEpoch 36, gen loss=-42.072940826416016,critic loss=-0.9855250716209412
#  9984/10000 [============================>.] - ETA: 0sEpoch 37, gen loss=-39.832035064697266,critic loss=-0.8993249535560608
#  9984/10000 [============================>.] - ETA: 0sEpoch 38, gen loss=-37.4063606262207,critic loss=-0.9489111304283142
#  9984/10000 [============================>.] - ETA: 0sEpoch 39, gen loss=-28.900327682495117,critic loss=-0.9255748391151428
#  9984/10000 [============================>.] - ETA: 0sEpoch 40, gen loss=-29.714305877685547,critic loss=-0.9901273846626282
#  9984/10000 [============================>.] - ETA: 0sEpoch 41, gen loss=-28.434213638305664,critic loss=-0.8848183751106262
#  9984/10000 [============================>.] - ETA: 0sEpoch 42, gen loss=-30.055904388427734,critic loss=-0.953324019908905
#  9984/10000 [============================>.] - ETA: 0sEpoch 43, gen loss=-25.734580993652344,critic loss=-0.9107769727706909
#  9984/10000 [============================>.] - ETA: 0sEpoch 44, gen loss=-27.467313766479492,critic loss=-0.9283320307731628
#  9984/10000 [============================>.] - ETA: 0sEpoch 45, gen loss=-24.479951858520508,critic loss=-0.8107879757881165
#  9984/10000 [============================>.] - ETA: 0sEpoch 46, gen loss=-34.75487518310547,critic loss=-0.7880059480667114
#  9984/10000 [============================>.] - ETA: 0sEpoch 47, gen loss=-36.93241500854492,critic loss=-0.7533565163612366
#  9984/10000 [============================>.] - ETA: 0sEpoch 48, gen loss=-36.285064697265625,critic loss=-0.7676342725753784
#  9984/10000 [============================>.] - ETA: 0sEpoch 49, gen loss=-28.850194931030273,critic loss=-0.7639538645744324
#  9984/10000 [============================>.] - ETA: 0sEpoch 50, gen loss=-24.363311767578125,critic loss=-0.8845431208610535

# %%
os.mkdir("/kaggle/working/saved_models")
tf.saved_model.save(gen , "/kaggle/working/saved_models")

# %%
noise = tf.random.normal([1,100])
image = gen(noise).numpy()
image = image.reshape(224,224,3)
plt.imshow(image  )

# %%
#mode collapse is not observed 


noises = np.random.randn(10,100)
images = []
noises[0].reshape(1,100)
for i in range(noises.shape[0]):
    images.append(gen(noises[i].reshape(1,100)).numpy().reshape(224,224,3))

fig , ax = plt.subplots(2,5 , figsize = (10,8))

for j in range(2):
  for i in range(5):
    plt.sca(ax[j][i])
    if j == 0:
      plt.imshow(images[i] )
    else:
      plt.imshow(images[i+5])
    plt.axis("off")
    plt.tight_layout()

# %%
plt.figure(figsize=(10,8))
plt.plot(G_loss , label = "Generator loss" , linewidth = 1.5)
plt.plot(C_loss, label = "Critic's loss" , linewidth = 1.5)
plt.legend()
plt.title("Loss per Epoch")
plt.show()
