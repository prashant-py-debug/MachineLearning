# %%
# !pip install librosa

# %%
import numpy as np
from IPython.display import Audio
import librosa
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = [ 12, 18]
plt.rcParams.update({"font.size" : 18})

# %%
dt = 0.001
t = np.arange(0, 2 , dt)
f0 = 50
f1 = 250
t1 = 2
x = np.cos(2*np.pi*t*(f0 + (f1 - f0) * np.power(t,2)/(3*t1**2)))

fs = 1/dt
Audio(data = x  , rate = 2 * len(t) )
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.specgram(x , NFFT = 128 , Fs = fs , noverlap=120, cmap = "jet_r")
plt.colorbar()
plt.show()

# %%
y , sr = librosa.load("/content/beethoven.mp3")

# %%
sr
# Out:
# 22050

# %%
Audio(y[:200000], rate = sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.specgram(y[:200000] , NFFT = 5000 , Fs = sr , noverlap=400 , cmap = "jet_r")
plt.colorbar()
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py:7592: RuntimeWarning: divide by zero encountered in log10
#   Z = 10. * np.log10(spec)
